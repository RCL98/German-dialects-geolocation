# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
cd drive/MyDrive/ML_German/code
# Out:
# /content/drive/MyDrive/ML_German/code

# %%
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
from nltk.corpus import stopwords
import pandas as pd
import numpy as np
from sklearn.model_selection import KFold 
import joblib
from string import punctuation

# %%
kf = KFold(n_splits=4, random_state=42, shuffle=True)

# %%
training_data = pd.read_csv('../csv_files/training_no_emoji.csv')

# %%
german_stopwwords = nltk.corpus.stopwords.words('german')
allowed_charachters = [ch for ch in ' abcdefghijklmnopqrstuvwxyz' + 'öäüß']
def filter_texts(texts):
  return [''.join([ch for ch in text.lower() if ch in allowed_charachters]) for text in texts if text not in german_stopwwords]

# %%
t = 0
for train_index, test_index in kf.split(training_data):
    X_train, X_test = filter_texts(training_data['Text'][train_index]), filter_texts(training_data['Text'][test_index])
    y_train , y_test = training_data['Lat'][train_index], training_data['Lat'][test_index]
    with open('./texts/train_text' + str(t) + '.txt', "w") as file:
      for text in X_train:
        file.write(text + "\n")
    with open('./texts/train_lat' + str(t) + '.txt', "w") as file:
      for lat in y_train:
        file.write(str(lat) + "\n")
    with open('./texts/test_text' + str(t) + '.txt', "w") as file:
      for text in X_test:
        file.write(text + "\n")
    with open('./texts/test_lat' + str(t) + '.txt', "w") as file:
      for lat in y_test:
        file.write(str(lat) + "\n")
    t += 1

# %%
# !java -Xmx5096m ComputeStringKernel 1 spectrum 3 5 ./texts/train_text0.txt ./kernels/train_kern0.txt
# Out:
# Loaded 16937 samples from ./texts/train_text0.txt
# Computing the spectrum kernel based on 3-5-grams ...
# Computed kernel to row 99 in 96506 ms
# Computed kernel to row 199 in 91677 ms
# Computed kernel to row 299 in 98464 ms
# Computed kernel to row 399 in 90429 ms
# Computed kernel to row 499 in 94533 ms
# Computed kernel to row 599 in 92208 ms
# Computed kernel to row 699 in 91483 ms
# Computed kernel to row 799 in 87309 ms
# Computed kernel to row 899 in 90769 ms
# Computed kernel to row 999 in 87746 ms
# Computed kernel to row 1099 in 91834 ms
# Computed kernel to row 1199 in 87793 ms
# Computed kernel to row 1299 in 86937 ms
# Computed kernel to row 1399 in 84749 ms
# Computed kernel to row 1499 in 86303 ms
# Computed kernel to row 1599 in 84893 ms
# Computed kernel to row 1699 in 84914 ms
# Computed kernel to row 1799 in 83955 ms
# Computed kernel to row 1899 in 84878 ms
# Computed kernel to row 1999 in 85613 ms
# Computed kernel to row 2099 in 82222 ms
# Computed kernel to row 2199 in 83067 ms
# Computed kernel to row 2299 in 81582 ms
# Computed kernel to row 2399 in 79581 ms
# Computed kernel to row 2499 in 77175 ms
# Computed kernel to row 2599 in 82394 ms
# Computed kernel to row 2699 in 78873 ms
# Computed kernel to row 2799 in 75978 ms
# Computed kernel to row 2899 in 78655 ms
# Computed kernel to row 2999 in 79622 ms
# Computed kernel to row 3099 in 80880 ms
# Computed kernel to row 3199 in 76967 ms
# Computed kernel to row 3299 in 77887 ms
# Computed kernel to row 3399 in 74166 ms
# Computed kernel to row 3499 in 76058 ms
# Computed kernel to row 3599 in 73448 ms
# Computed kernel to row 3699 in 71429 ms
# Computed kernel to row 3799 in 74635 ms
# Computed kernel to row 3899 in 70963 ms
# Computed kernel to row 3999 in 73797 ms
# Computed kernel to row 4099 in 72440 ms
# Computed kernel to row 4199 in 71275 ms
# Computed kernel to row 4299 in 70901 ms
# Computed kernel to row 4399 in 70673 ms
# Computed kernel to row 4499 in 69364 ms
# Computed kernel to row 4599 in 69132 ms
# Computed kernel to row 4699 in 69290 ms
# Computed kernel to row 4799 in 64949 ms
# Computed kernel to row 4899 in 70151 ms
# Computed kernel to row 4999 in 69415 ms
# Computed kernel to row 5099 in 65920 ms
# Computed kernel to row 5199 in 65808 ms
# Computed kernel to row 5299 in 67192 ms
# Computed kernel to row 5399 in 64453 ms
# Computed kernel to row 5499 in 64724 ms
# Computed kernel to row 5599 in 65467 ms
# Computed kernel to row 5699 in 61425 ms
# Computed kernel to row 5799 in 60538 ms
# Computed kernel to row 5899 in 60997 ms
# Computed kernel to row 5999 in 62643 ms
# Computed kernel to row 6099 in 61309 ms
# Computed kernel to row 6199 in 61236 ms
# Computed kernel to row 6299 in 60999 ms
# Computed kernel to row 6399 in 59453 ms
# Computed kernel to row 6499 in 57572 ms
# Computed kernel to row 6599 in 57208 ms
# Computed kernel to row 6699 in 57201 ms
# Computed kernel to row 6799 in 58319 ms
# Computed kernel to row 6899 in 59383 ms
# Computed kernel to row 6999 in 55709 ms
# Computed kernel to row 7099 in 54455 ms
# Computed kernel to row 7199 in 56272 ms
# Computed kernel to row 7299 in 57731 ms
# Computed kernel to row 7399 in 51180 ms
# Computed kernel to row 7499 in 54630 ms
# Computed kernel to row 7599 in 52253 ms
# Computed kernel to row 7699 in 52438 ms
# Computed kernel to row 7799 in 50725 ms
# Computed kernel to row 7899 in 51735 ms
# Computed kernel to row 7999 in 51417 ms
# Computed kernel to row 8099 in 50216 ms
# Computed kernel to row 8199 in 48418 ms
# Computed kernel to row 8299 in 47833 ms
# Computed kernel to row 8399 in 47354 ms
# Computed kernel to row 8499 in 48348 ms
# Computed kernel to row 8599 in 46729 ms
# Computed kernel to row 8699 in 44881 ms
# Computed kernel to row 8799 in 46032 ms
# Computed kernel to row 8899 in 44241 ms
# Computed kernel to row 8999 in 43892 ms
# Computed kernel to row 9099 in 45152 ms
# Computed kernel to row 9199 in 43737 ms
# Computed kernel to row 9299 in 42536 ms
# Computed kernel to row 9399 in 43476 ms
# Computed kernel to row 9499 in 43140 ms
# Computed kernel to row 9599 in 40975 ms
# Computed kernel to row 9699 in 42374 ms
# Computed kernel to row 9799 in 38002 ms
# Computed kernel to row 9899 in 39599 ms
# Computed kernel to row 9999 in 39578 ms
# Computed kernel to row 10099 in 39657 ms
# Computed kernel to row 10199 in 38992 ms
# Computed kernel to row 10299 in 39184 ms
# Computed kernel to row 10399 in 36065 ms
# Computed kernel to row 10499 in 36571 ms
# Computed kernel to row 10599 in 35212 ms
# Computed kernel to row 10699 in 35231 ms
# Computed kernel to row 10799 in 34224 ms
# Computed kernel to row 10899 in 32232 ms
# Computed kernel to row 10999 in 33095 ms
# Computed kernel to row 11099 in 32958 ms
# Computed kernel to row 11199 in 34478 ms
# Computed kernel to row 11299 in 29879 ms
# Computed kernel to row 11399 in 31682 ms
# Computed kernel to row 11499 in 29024 ms
# Computed kernel to row 11599 in 29968 ms
# Computed kernel to row 11699 in 29388 ms
# Computed kernel to row 11799 in 30198 ms
# Computed kernel to row 11899 in 29584 ms
# Computed kernel to row 11999 in 28497 ms
# Computed kernel to row 12099 in 27261 ms
# Computed kernel to row 12199 in 28466 ms
# Computed kernel to row 12299 in 26087 ms
# Computed kernel to row 12399 in 26188 ms
# Computed kernel to row 12499 in 25357 ms
# Computed kernel to row 12599 in 25257 ms
# Computed kernel to row 12699 in 23695 ms
# Computed kernel to row 12799 in 22960 ms
# Computed kernel to row 12899 in 22625 ms
# Computed kernel to row 12999 in 22813 ms
# Computed kernel to row 13099 in 22573 ms
# Computed kernel to row 13199 in 22288 ms
# Computed kernel to row 13299 in 21778 ms
# Computed kernel to row 13399 in 21234 ms
# Computed kernel to row 13499 in 20388 ms
# Computed kernel to row 13599 in 19204 ms
# Computed kernel to row 13699 in 19562 ms
# Computed kernel to row 13799 in 18906 ms
# Computed kernel to row 13899 in 17235 ms
# Computed kernel to row 13999 in 17229 ms
# Computed kernel to row 14099 in 18180 ms
# Computed kernel to row 14199 in 15803 ms
# Computed kernel to row 14299 in 15429 ms
# Computed kernel to row 14399 in 15235 ms
# Computed kernel to row 14499 in 13872 ms
# Computed kernel to row 14599 in 13838 ms
# Computed kernel to row 14699 in 13712 ms
# Computed kernel to row 14799 in 12487 ms
# Computed kernel to row 14899 in 12208 ms
# Computed kernel to row 14999 in 12179 ms
# Computed kernel to row 15099 in 10857 ms
# Computed kernel to row 15199 in 10361 ms
# Computed kernel to row 15299 in 10086 ms
# Computed kernel to row 15399 in 9263 ms
# Computed kernel to row 15499 in 8700 ms
# Computed kernel to row 15599 in 8038 ms
# Computed kernel to row 15699 in 7539 ms
# Computed kernel to row 15799 in 6876 ms
# Computed kernel to row 15899 in 6334 ms
# Computed kernel to row 15999 in 5545 ms
# Computed kernel to row 16099 in 5206 ms
# Computed kernel to row 16199 in 4450 ms
# Computed kernel to row 16299 in 3876 ms
# Computed kernel to row 16399 in 3406 ms
# Computed kernel to row 16499 in 2942 ms
# Computed kernel to row 16599 in 2252 ms
# Computed kernel to row 16699 in 1711 ms
# Computed kernel to row 16799 in 1068 ms
# Computed kernel to row 16899 in 602 ms
# Elasped time 8046147 ms
# Saving kernel matrix to ./kernels/train_kern0.txt ...

# %%
# with open('./kernels/train_kern0.txt', "r") as file:
#   mat = [[int(num) for num in line.split(' ') if num != '\n'] for line in file]
# training_kernel = np.array(mat)
# np.savez_compressed('./kernels/train_kernel0.npz', training_kernel)

# %%
with open('./texts/train_lat0.txt', "r") as file:
  mat = [[float(num) for num in line.split(' ') if num != '\n'] for line in file]
training_lats0 = np.array(mat)

# %%
# with open('./kernels/test_kern0.txt', "r") as file:
#   mat = [[int(num) for num in line.split(' ') if num != '\n'] for line in file]
# test_kernel = np.array(mat)
# np.savez_compressed('./kernels/test_kernel0.npz', test_kernel)

# %%
with open('./texts/test_lat0.txt', "r") as file:
  mat = [[float(num) for num in line.split(' ') if num != '\n'] for line in file]
test_lats0 = np.array(mat)

# %%
train_kern = np.load('./kernels/train_kernel0.npz')['arr_0']
test_kern = np.load('./kernels/test_kernel0.npz')['arr_0']

# %%
from sklearn.svm import SVR, NuSVR
from sklearn.kernel_ridge import KernelRidge
import joblib
from sklearn.metrics import mean_absolute_error as MAE
from sklearn.metrics import mean_squared_error as MSE

# %%
nuSvr = NuSVR(C = 10, kernel='precomputed', cache_size = 2000, max_iter = 10**8)

# %%
nuSvr.fit(training_kernel, training_lats0.ravel())
# Out:
# NuSVR(C=10, cache_size=2000, coef0=0.0, degree=3, gamma='scale',
#       kernel='precomputed', max_iter=100000000, nu=0.5, shrinking=True,
#       tol=0.001, verbose=False)

# %%
preds = nuSvr.predict(np.transpose(test_kernel))

# %%
MAE(preds, test_lats0.ravel())
# Out:
# 0.7846815335811589

# %%
kernRidge = KernelRidge(kernel='precomputed')

# %%
kernRidge.fit(train_kern, training_lats0.ravel())
# Out:
# KernelRidge(alpha=1, coef0=1, degree=3, gamma=None, kernel='precomputed',
#             kernel_params=None)

# %%
preds = kernRidge.predict(np.transpose(test_kern))

# %%
MAE(preds, test_lats0.ravel())
# Out:
# 27.64934823221933

# %%
joblib.dump(nuSvr, './nuSvr_1.pkl')
# Out:
# ['./nuSvr_1.pkl']

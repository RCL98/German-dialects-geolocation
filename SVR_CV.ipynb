# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
cd drive/MyDrive/ML_German
# Out:
# /content/drive/MyDrive/ML_German

# %%
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
from nltk.corpus import stopwords
import pandas as pd
import numpy as np
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer 
from sklearn.model_selection import KFold 
from sklearn.svm import SVR, NuSVR
from sklearn.preprocessing import StandardScaler, MinMaxScaler, RobustScaler
import joblib
from string import punctuation
from sklearn.metrics import mean_absolute_error as MAE
from sklearn.metrics import mean_squared_error as MSE
from sklearn.model_selection import train_test_split

# %%
def cross_validation(model, train_kernels, train_lats, test_kernels, test_lats, scaler = None, scaler2 = None):
  maes_sum = 0 
  for tr_kern, tr_lats, tst_kern, tst_lats in zip(train_kernels, train_lats, test_kernels, test_lats):
    kernel = np.load(tr_kern)['arr_0']
    if scaler is not None:
      kernel = scaler.fit_transform(kernel)
    with open(tr_lats, "r") as file:
      mat = [[float(num) for num in line.split(' ') if num != '\n'] for line in file]
    train_lats_ = np.array(mat)
    if scaler2 is not None:
      train_lats_ = scaler2.fit_transform(train_lats_)

    model.fit(kernel, train_lats_.ravel())
    
    kernel = np.load(tst_kern)['arr_0']
    if scaler is not None:
      kernel = scaler.transform(kernel)
    with open(tst_lats, "r") as file:
      mat = [[float(num) for num in line.split(' ') if num != '\n'] for line in file]
    test_lats_ = np.array(mat)
    if scaler2 is not None:
      test_lats_  = scaler2.transform(test_lats_ )
    predictions = model.predict(kernel)

    mae = 0
    for pred, lat in zip(predictions, test_lats_.ravel()):
      mae += abs(pred - lat)
    print(mae / len(predictions), end = ' ')
    maes_sum += mae / len(predictions)
  print("\nFinal sum: ", maes_sum / 4)

# %%
train_kernels = ['./kernels/train_kernel' + str(i) + '.npz' for i in range(4)]
train_lats = ['./texts/train_lat' + str(i) + '.txt' for i in range(4)]
test_kernels = ['./kernels/test_kernel' + str(i) + '.npz' for i in range(4)]
test_lats = ['./texts/test_lat' + str(i) + '.txt' for i in range(4)]

# %%
nuSvr = NuSVR(kernel = 'precomputed', cache_size = 1500, max_iter = 10**7)

# %%
cross_validation(nuSvr, train_kernels, train_lats, test_kernels, test_lats)
# Out:
# 0.7351710825371262 0.7426166033489675 0.7371014613695526 0.7300427857136514
# Final sum:  0.7362329832423244

# %%
nuSvr1 = NuSVR(C = 10, kernel = 'precomputed', cache_size = 1500, max_iter = 10**7)

# %%
cross_validation(nuSvr1, train_kernels, train_lats, test_kernels, test_lats)
# Out:
# 0.7351633282902392 0.7426165460703571 0.7370953208365569 0.730050566958823
# Final sum:  0.736231440538994

# %%
Svr = SVR(kernel = 'precomputed', cache_size = 1500, max_iter = 10**7)

# %%
cross_validation(Svr, train_kernels, train_lats, test_kernels, test_lats)
# Out:
# 0.7104264599542969 0.7161269411489446 0.7121362346947109 0.7066528656546831
# Final sum:  0.7113356253631589

# %%
Svr1 = SVR(kernel = 'precomputed', cache_size = 1500, max_iter = 10**8)

# %%
cross_validation(Svr1, train_kernels, train_lats, test_kernels, test_lats)
# Out:
# 0.7104264599542969 0.7161269411489446 0.7121362346947109 0.7066528656546831
# Final sum:  0.7113356253631589

# %%
std_scaler = StandardScaler()
Svr1 = SVR(kernel = 'precomputed', cache_size = 1500, max_iter = 10**8)

# %%
cross_validation(Svr1, train_kernels, train_lats, test_kernels, test_lats, std_scaler)
# Out:
# 9.050413997337134 11.133035939974246 10.6845831129904 10.093087971596146
# Final sum:  10.240280255474481

# %%
mnm_scaler = MinMaxScaler()
Svr1 = SVR(kernel = 'precomputed', cache_size = 1500, max_iter = 10**8)

# %%
cross_validation(Svr1, train_kernels, train_lats, test_kernels, test_lats, mnm_scaler)
# Out:
# 927.5927906199399 937.791371011961 941.8398528862931 951.9316337347775
# Final sum:  939.7889120632428

# %%
std_scaler1 = StandardScaler()
std_scaler2 = StandardScaler()
Svr1 = SVR(kernel = 'precomputed', cache_size = 1500, max_iter = 10**8)

# %%
cross_validation(Svr1, train_kernels, train_lats, test_kernels, test_lats, std_scaler1, std_scaler2)
# Out:
# 10.052607571447535 12.306302717782469 11.90161826591568 11.260747803887305
# Final sum:  11.380319089758247

# %% [markdown]
# New Try

# %%
training_data = pd.read_csv('./csv_files/training_no_emoji.csv')
validation_data = pd.read_csv('./csv_files/validation_no_emoji.csv')

# %%
german_stopwords = stopwords.words('german')

# %%
allowed_charachters = [ch for ch in ' abcdefghijklmnopqrstuvwxyz' + 'öäüß']
def filter_texts(texts):
  return [''.join([ch for ch in text.lower() if ch in allowed_charachters]) for text in texts]

# %%
y_lats = training_data['Lat']
y_longs = training_data['Long']
y_values = np.array([[lat, lon] for lat, lon in zip(y_lats, y_longs)])

# %%
count_vect = TfidfVectorizer(stop_words= german_stopwords , ngram_range=(3, 5), analyzer='char', max_features=60000)

# %%
data_train, data_test, values_train, values_test = train_test_split(training_data['Text'], y_values, test_size=0.2, random_state = 0)

# %%
data_train, values_train = training_data['Text'], training_data['Lat']
data_test, values_test = validation_data['Text'], validation_data['Lat']

# %%
data_train = filter_texts(data_train)
data_test = filter_texts(data_test)

# %%
X_train = count_vect.fit_transform(data_train)
X_test = count_vect.transform(data_test)

# %%
from sklearn.ensemble import GradientBoostingRegressor

# %%
GradientBoostingRegressor(n_iter_no_change=5, learning_rate=0.1, n_estimators=250, max_depth=40, random_state=0, alpha=0.8, ccp_alpha=0.0, max_features='auto', loss='huber')
# Out:
# GradientBoostingRegressor(alpha=0.8, ccp_alpha=0.0, criterion='friedman_mse',
#                           init=None, learning_rate=0.1, loss='huber',
#                           max_depth=40, max_features='auto',
#                           max_leaf_nodes=None, min_impurity_decrease=0.0,
#                           min_impurity_split=None, min_samples_leaf=1,
#                           min_samples_split=2, min_weight_fraction_leaf=0.0,
#                           n_estimators=250, n_iter_no_change=5,
#                           presort='deprecated', random_state=0, subsample=1.0,
#                           tol=0.0001, validation_fraction=0.1, verbose=0,
#                           warm_start=False)

# %%
gdR.fit(X_train, values_train[:,1])
# Out:
#       Iter       Train Loss   Remaining Time
#          1           0.8657           24.04m
#          2           0.8263           23.09m
#          3           0.7907           22.73m
#          4           0.7650           22.59m
#          5           0.7430           22.41m
#          6           0.7214           22.28m
#          7           0.7039           22.17m
#          8           0.6834           22.07m
#          9           0.6651           21.99m
#         10           0.6505           21.92m
#         20           0.5444           21.22m
#         30           0.4900           20.52m
#         40           0.4581           19.85m
#         50           0.4365           19.19m
#         60           0.4208           18.54m
#         70           0.4066           17.89m
#         80           0.3958           17.24m
#         90           0.3867           16.59m
#        100           0.3787           15.93m
#        200           0.3240            9.52m
#        300           0.2911            3.16m
# GradientBoostingRegressor(alpha=0.8, ccp_alpha=0.0, criterion='friedman_mse',
#                           init=None, learning_rate=0.1, loss='huber',
#                           max_depth=3, max_features=None, max_leaf_nodes=None,
#                           min_impurity_decrease=0.0, min_impurity_split=None,
#                           min_samples_leaf=1, min_samples_split=2,
#                           min_weight_fraction_leaf=0.0, n_estimators=350,
#                           n_iter_no_change=5, presort='deprecated',
#                           random_state=0, subsample=1.0, tol=0.0001,
#                           validation_fraction=0.1, verbose=1, warm_start=False)

# %%
predict = gdR.predict(X_test)

# %%
MAE(values_test[:,1], predict)
# Out:
# 0.6900410443724461

# %% [markdown]
# 0.7015082995980139

# %%
from sklearn.linear_model import SGDRegressor

# %%
sgd = SGDRegressor(max_iter=10**9, learning_rate='adaptive', eta0 = 0.1)

# %%
sgd.fit(X_train, values_train)
# Out:
# SGDRegressor(alpha=0.0001, average=False, early_stopping=False, epsilon=0.1,
#              eta0=0.1, fit_intercept=True, l1_ratio=0.15,
#              learning_rate='adaptive', loss='squared_loss', max_iter=1000000000,
#              n_iter_no_change=5, penalty='l2', power_t=0.25, random_state=None,
#              shuffle=True, tol=0.001, validation_fraction=0.1, verbose=0,
#              warm_start=False)

# %%
predict = sgd.predict(X_test)
MAE(values_test, predict)
# Out:
# 0.5101271714044763

# %% [markdown]
# 0.511059081600427 0.5101384689212188

# %%
sgd1 = SGDRegressor(max_iter=10**9, learning_rate='adaptive', eta0 = 0.01)

# %%
sgd1.fit(X_train, values_train[:,1])
# Out:
# SGDRegressor(alpha=0.0001, average=False, early_stopping=False, epsilon=0.1,
#              eta0=0.01, fit_intercept=True, l1_ratio=0.15,
#              learning_rate='adaptive', loss='squared_loss', max_iter=1000000000,
#              n_iter_no_change=5, penalty='l2', power_t=0.25, random_state=None,
#              shuffle=True, tol=0.001, validation_fraction=0.1, verbose=0,
#              warm_start=False)

# %%
predict1 = sgd1.predict(X_test)
MAE(values_test[:,1], predict1)
# Out:
# 0.6976766426253173

# %%
MAE(values_test[:,0], predict) + MAE(values_test[:,1], predict1) / 2
# Out:
# 0.8676358277977503

# %%
mae = 0
for pred, pred1, val, val1 in zip(predict, predict1, values_test[:,0], values_test[:,1]):
  mae += abs(pred - val) + abs(pred1 - val1)
print(mae/(2 * len(predict)))
# Out:
# 0.6082370745552064

# %%
svr = NuSVR(nu = 0.5, C = 10, cache_size = 1500, max_iter = 10**8)

# %%
svr.fit(X_train, values_train)
# Out:
# NuSVR(C=10, cache_size=1500, coef0=0.0, degree=3, gamma='scale', kernel='rbf',
#       max_iter=100000000, nu=0.5, shrinking=True, tol=0.001, verbose=False)

# %%
predict = svr.predict(X_test)

# %%
MAE(values_test, predict)
# Out:
# 0.5074418052945137

# %%
joblib.dump(svr, 'nuSVR.pkl')
# Out:
# ['nuSVR.pkl']

# %%
svr1 = SVR(cache_size = 1500, max_iter = 10**8, kernel = 'linear')

# %%
svr1.fit(X_train, values_train)
# Out:
# SVR(C=1.0, cache_size=1500, coef0=0.0, degree=3, epsilon=0.1, gamma='scale',
#     kernel='linear', max_iter=100000000, shrinking=True, tol=0.001,
#     verbose=False)

# %%
predict = svr1.predict(X_test)
MAE(values_test, predict)
# Out:
# 0.5429949649910263

# %%
# !java -Xmx5096m ComputeStringKernel 2 spectrum 3 5 ./texts/train_text0.txt ./texts/test_text0.txt ./kernels/test_kern0.txt
# Out:
# Loaded 16937 samples from ./texts/train_text0.txt
# Loaded 5646 samples from ./texts/test_text0.txt
# Computing the spectrum kernel based on 3-5-grams ...
# Computed kernel to row 99 in 36409 ms
# Computed kernel to row 199 in 34379 ms
# Computed kernel to row 299 in 37066 ms
# Computed kernel to row 399 in 34151 ms
# Computed kernel to row 499 in 36299 ms
# Computed kernel to row 599 in 35935 ms
# Computed kernel to row 699 in 35627 ms
# Computed kernel to row 799 in 33794 ms
# Computed kernel to row 899 in 35523 ms
# Computed kernel to row 999 in 34115 ms
# Computed kernel to row 1099 in 36182 ms
# Computed kernel to row 1199 in 34880 ms
# Computed kernel to row 1299 in 34810 ms
# Computed kernel to row 1399 in 34485 ms
# Computed kernel to row 1499 in 35410 ms
# Computed kernel to row 1599 in 35269 ms
# Computed kernel to row 1699 in 35588 ms
# Computed kernel to row 1799 in 35456 ms
# Computed kernel to row 1899 in 36286 ms
# Computed kernel to row 1999 in 36769 ms
# Computed kernel to row 2099 in 34673 ms
# Computed kernel to row 2199 in 36438 ms
# Computed kernel to row 2299 in 35436 ms
# Computed kernel to row 2399 in 34991 ms
# Computed kernel to row 2499 in 33793 ms
# Computed kernel to row 2599 in 36199 ms
# Computed kernel to row 2699 in 36409 ms
# Computed kernel to row 2799 in 33510 ms
# Computed kernel to row 2899 in 35993 ms
# Computed kernel to row 2999 in 36144 ms
# Computed kernel to row 3099 in 36848 ms
# Computed kernel to row 3199 in 35528 ms
# Computed kernel to row 3299 in 35464 ms
# Computed kernel to row 3399 in 34412 ms
# Computed kernel to row 3499 in 34703 ms
# Computed kernel to row 3599 in 34995 ms
# Computed kernel to row 3699 in 33639 ms
# Computed kernel to row 3799 in 35382 ms
# Computed kernel to row 3899 in 33536 ms
# Computed kernel to row 3999 in 35252 ms
# Computed kernel to row 4099 in 34894 ms
# Computed kernel to row 4199 in 34145 ms
# Computed kernel to row 4299 in 34386 ms
# Computed kernel to row 4399 in 35049 ms
# Computed kernel to row 4499 in 35331 ms
# Computed kernel to row 4599 in 35338 ms
# Computed kernel to row 4699 in 35508 ms
# Computed kernel to row 4799 in 33899 ms
# Computed kernel to row 4899 in 36745 ms
# Computed kernel to row 4999 in 36278 ms
# Computed kernel to row 5099 in 34850 ms
# Computed kernel to row 5199 in 34999 ms
# Computed kernel to row 5299 in 36531 ms
# Computed kernel to row 5399 in 34966 ms
# Computed kernel to row 5499 in 35495 ms
# Computed kernel to row 5599 in 36132 ms
# Computed kernel to row 5699 in 34975 ms
# Computed kernel to row 5799 in 34460 ms
# Computed kernel to row 5899 in 35348 ms
# Computed kernel to row 5999 in 36141 ms
# Computed kernel to row 6099 in 35839 ms
# Computed kernel to row 6199 in 35802 ms
# Computed kernel to row 6299 in 35962 ms
# Computed kernel to row 6399 in 35776 ms
# Computed kernel to row 6499 in 34535 ms
# Computed kernel to row 6599 in 35025 ms
# Computed kernel to row 6699 in 35728 ms
# Computed kernel to row 6799 in 36790 ms
# Computed kernel to row 6899 in 37687 ms
# Computed kernel to row 6999 in 35460 ms
# Computed kernel to row 7099 in 34913 ms
# Computed kernel to row 7199 in 37009 ms
# Computed kernel to row 7299 in 38267 ms
# Computed kernel to row 7399 in 33592 ms
# Computed kernel to row 7499 in 36663 ms
# Computed kernel to row 7599 in 35265 ms
# Computed kernel to row 7699 in 35771 ms
# Computed kernel to row 7799 in 35032 ms
# Computed kernel to row 7899 in 36259 ms
# Computed kernel to row 7999 in 36841 ms
# Computed kernel to row 8099 in 35887 ms
# Computed kernel to row 8199 in 35352 ms
# Computed kernel to row 8299 in 34505 ms
# Computed kernel to row 8399 in 35225 ms
# Computed kernel to row 8499 in 35955 ms
# Computed kernel to row 8599 in 35399 ms
# Computed kernel to row 8699 in 34244 ms
# Computed kernel to row 8799 in 35710 ms
# Computed kernel to row 8899 in 34653 ms
# Computed kernel to row 8999 in 34104 ms
# Computed kernel to row 9099 in 36617 ms
# Computed kernel to row 9199 in 36140 ms
# Computed kernel to row 9299 in 35030 ms
# Computed kernel to row 9399 in 36106 ms
# Computed kernel to row 9499 in 36574 ms
# Computed kernel to row 9599 in 34644 ms
# Computed kernel to row 9699 in 36712 ms
# Computed kernel to row 9799 in 33016 ms
# Computed kernel to row 9899 in 34571 ms
# Computed kernel to row 9999 in 35826 ms
# Computed kernel to row 10099 in 36865 ms
# Computed kernel to row 10199 in 36745 ms
# Computed kernel to row 10299 in 36971 ms
# Computed kernel to row 10399 in 34937 ms
# Computed kernel to row 10499 in 36317 ms
# Computed kernel to row 10599 in 34923 ms
# Computed kernel to row 10699 in 35223 ms
# Computed kernel to row 10799 in 35383 ms
# Computed kernel to row 10899 in 33929 ms
# Computed kernel to row 10999 in 35347 ms
# Computed kernel to row 11099 in 34982 ms
# Computed kernel to row 11199 in 37207 ms
# Computed kernel to row 11299 in 32517 ms
# Computed kernel to row 11399 in 35594 ms
# Computed kernel to row 11499 in 33645 ms
# Computed kernel to row 11599 in 34724 ms
# Computed kernel to row 11699 in 34823 ms
# Computed kernel to row 11799 in 37083 ms
# Computed kernel to row 11899 in 36781 ms
# Computed kernel to row 11999 in 36086 ms
# Computed kernel to row 12099 in 34702 ms
# Computed kernel to row 12199 in 38127 ms
# Computed kernel to row 12299 in 35041 ms
# Computed kernel to row 12399 in 36026 ms
# Computed kernel to row 12499 in 36185 ms
# Computed kernel to row 12599 in 35759 ms
# Computed kernel to row 12699 in 34752 ms
# Computed kernel to row 12799 in 34871 ms
# Computed kernel to row 12899 in 35342 ms
# Computed kernel to row 12999 in 36373 ms
# Computed kernel to row 13099 in 35771 ms
# Computed kernel to row 13199 in 35534 ms
# Computed kernel to row 13299 in 35571 ms
# Computed kernel to row 13399 in 34876 ms
# Computed kernel to row 13499 in 35025 ms
# Computed kernel to row 13599 in 33511 ms
# Computed kernel to row 13699 in 36112 ms
# Computed kernel to row 13799 in 35465 ms
# Computed kernel to row 13899 in 32863 ms
# Computed kernel to row 13999 in 33556 ms
# Computed kernel to row 14099 in 37421 ms
# Computed kernel to row 14199 in 33309 ms
# Computed kernel to row 14299 in 34469 ms
# Computed kernel to row 14399 in 35441 ms
# Computed kernel to row 14499 in 32906 ms
# Computed kernel to row 14599 in 34800 ms
# Computed kernel to row 14699 in 36460 ms
# Computed kernel to row 14799 in 34150 ms
# Computed kernel to row 14899 in 35341 ms
# Computed kernel to row 14999 in 36821 ms
# Computed kernel to row 15099 in 34537 ms
# Computed kernel to row 15199 in 34455 ms
# Computed kernel to row 15299 in 36677 ms
# Computed kernel to row 15399 in 35121 ms
# Computed kernel to row 15499 in 34988 ms
# Computed kernel to row 15599 in 34985 ms
# Computed kernel to row 15699 in 35507 ms
# Computed kernel to row 15799 in 34544 ms
# Computed kernel to row 15899 in 35527 ms
# Computed kernel to row 15999 in 33611 ms
# Computed kernel to row 16099 in 35117 ms
# Computed kernel to row 16199 in 34122 ms
# Computed kernel to row 16299 in 33646 ms
# Computed kernel to row 16399 in 33656 ms
# Computed kernel to row 16499 in 35927 ms
# Computed kernel to row 16599 in 34877 ms
# Computed kernel to row 16699 in 35192 ms
# Computed kernel to row 16799 in 33266 ms
# Computed kernel to row 16899 in 36299 ms
# Elasped time 5970450 ms
# Saving kernel matrix to ./kernels/test_kern0.txt ...

# %% [markdown]
# 0.5195345785945145
